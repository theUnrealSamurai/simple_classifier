# %%
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("/Users/mits-mac-001/Code/simple_classifier/anamoly_detection/motor_data.csv")
df.head(20)
# Out:
#                    Time  Motor Voltage  Motor Current  Capacitor Voltage  \
# 0   2024-01-01 00:00:00     222.483571      22.798711         393.248217
# 1   2024-01-01 01:00:00     219.308678      21.849267         398.554813
# 2   2024-01-01 02:00:00     223.238443      20.119261         392.075801
# 3   2024-01-01 03:00:00     227.615149      18.706126         396.920385
# 4   2024-01-01 04:00:00     218.829233      21.396447         381.063853
# 5   2024-01-01 05:00:00     218.829315      20.786971         402.132937
# 6   2024-01-01 06:00:00     227.896064      21.790386         400.012055
# 7   2024-01-01 07:00:00     223.837174      21.270344         391.829114
# 8   2024-01-01 08:00:00     217.652628      22.099105         406.592457
# 9   2024-01-01 09:00:00     222.712800      18.929530         409.375701
# 10  2024-01-01 10:00:00     217.682912      22.634788         383.924401
# 11  2024-01-01 11:00:00     217.671351      20.395199         392.372752
# ...

# %%
#Visualization for Motor Voltage, Motor Current

plt.bar(df["Time"], df["Motor Voltage"], label="Time and Motor Voltage")
plt.show()
plt.bar(df["Time"], df["Motor Current"], label="Time and Motor Current")
plt.show()

# %%
plt.bar(df["Time"], df["Capacitor Voltage"], label="Time and Capacitor Voltage")
plt.show()
plt.bar(df["Time"], df["Capacitor Current"], label="Time and Capacitor Current")
plt.show()

# %%
plt.bar(df["Time"], df["Temperature"], label="Time and Temperature")
plt.show()
plt.scatter(df["Time"], df["Pressure"], label="Time and Pressure")
plt.show()
plt.plot(df["Time"], df["Humidity"], label="Time and Humidity")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 import numpy as np
#       4 # Load the dataset
# ----> 5 data = pd.read_csv('anamoly_detection/motor_data.csv')
#       7 # Define a function to detect anomalies using z-score
#       8 def detect_anomalies(series, threshold=3):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
