# %%
import pandas as pd
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/merged_data.csv")
df.head()
# Out:
#    No_of_Rotation_(excluding_bonus)  ...  setting
# 0                               1.0  ...        2
# 1                               2.0  ...        2
# 2                               3.0  ...        2
# 3                               4.0  ...        2
# 4                               5.0  ...        2
#
# [5 rows x 11 columns]

# %%
X, y = df.drop(columns=["setting"]), df["setting"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True)
print(len(X_train), len(X_test))
# Out:
# 152062 16896

# %%
model = XGBRegressor()
model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.9768229107034946

# %%
X_test.head()
# Out:
#         No_of_Rotation_(excluding_bonus)  ...  No_of_cherry_middle_till_now
# 146489                            5045.0  ...                             7
# 145328                            3884.0  ...                             6
# 69683                             7012.0  ...                             3
# 2440                              2441.0  ...                             2
# 146061                            4617.0  ...                             7
#
# [5 rows x 10 columns]

# %%
y_test.head()
# Out:
# 146489    5
# 145328    5
# 69683     3
# 2440      2
# 146061    5
# Name: setting, dtype: int64

# %%
model.predict([[617.0,1865,1198,1,0,103,81,11,0,0]])
# Out:
# array([0.90939534], dtype=float32)
